# %%
from sklearn.datasets import load_iris
df=load_iris()
x=df.data
feature=df.feature_names
feature
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
from sklearn.preprocessing import StandardScaler
scale=StandardScaler()
x_scale=scale.fit_transform(x)
from sklearn.cluster import KMeans
km=KMeans(n_clusters=3,n_init=10)
y_pred=km.fit_predict(x_scale)
import matplotlib.pyplot as plt
plt.scatter(x_scale[:,2],x_scale[:,3],c=y_pred)
plt.show()

# %%
import numpy as np
sse=[]
k_rng=np.arange(1,11)
for k in k_rng:
    km=KMeans(n_clusters=k,n_init=10)
    y_pred=km.fit_predict(x_scale)
    sse.append(km.inertia_)

plt.plot(k_rng,sse)
plt.show()

# %%
from sklearn.datasets import load_digits
import pandas as pd
digits=load_digits()
df=pd.DataFrame(digits.data,
                columns=digits.feature_names
                
                )
print(x)
print(feature)
# Out:
# [[ 0.  0.  5. ...  0.  0.  0.]
#  [ 0.  0.  0. ... 10.  0.  0.]
#  [ 0.  0.  0. ... 16.  9.  0.]
#  ...
#  [ 0.  0.  1. ...  6.  0.  0.]
#  [ 0.  0.  2. ... 12.  0.  0.]
#  [ 0.  0. 10. ... 12.  1.  0.]]
# ...

# %%
x_scale=scale.fit_transform(x)
k_rng=np.arange(1,10)
sse=[]
for k in k_rng:
    km=KMeans(n_clusters=k,n_init=10)
    y_pred=km.fit_predict(x_scale)
    sse.append(km.inertia_)
plt.scatter(x_scale[:,2],x_scale[:,3],c=y_pred)
plt.legend()
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_4220\825352080.py:9: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
plt.plot(k_rng,sse)
plt.show()

# %%
from sklearn.metrics import silhouette_score
score=silhouette_score(x_scale,y_pred)
score
# Out:
# 0.13379378281831916

# %%
df['cluster']=y_pred
mean=df.groupby('cluster').mean()

mean
# Out:
#          pixel_0_0  pixel_0_1  pixel_0_2  pixel_0_3  pixel_0_4  pixel_0_5  \
# cluster
# 0              0.0   0.000000   1.172222  11.150000   9.572222   1.577778
# 1              0.0   0.022599   4.248588  13.146893  11.225989   2.909605
# 2              0.0   0.290476   7.514286  13.297619  12.819048   6.647619
# 3              0.0   0.048193   7.180723  13.891566   7.614458   1.168675
# 4              0.0   0.000000   1.187500   8.125000  12.156250  10.375000
# 5              0.0   0.064171   4.877005  13.262032  14.037433  10.631016
# 6              0.0   0.076220   4.865854  12.423780  13.003049   6.865854
# 7              0.0   2.429487  13.224359  14.532051   9.980769   5.147436
# 8              0.0   0.000000   0.123932   4.764957  11.662393   5.670940
#
#          pixel_0_6  pixel_0_7  pixel_1_0  pixel_1_1  ...  pixel_6_6  \
# cluster                                              ...
# 0         0.066667   0.000000   0.000000   0.055556  ...  11.066667
# ...
